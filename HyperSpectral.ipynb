# %%
from spectral import *

img = open_image('92AV3C.lan').load()
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt 
import seaborn as sns 
from sklearn.cluster import KMeans
#print(os.listdir("../input"))

# %%
pip install spectral
# Out:
# Collecting spectral
#   Downloading https://files.pythonhosted.org/packages/48/8e/db1d750fb0153027e4e945f91f04b72a3b8b9a0cfdc2c8a33bedcb27740d/spectral-0.20.tar.gz (143kB)
# Requirement already satisfied: numpy in c:\users\dell\anaconda3\lib\site-packages (from spectral) (1.16.4)
# Building wheels for collected packages: spectral
#   Building wheel for spectral (setup.py): started
#   Building wheel for spectral (setup.py): finished with status 'done'
#   Stored in directory: C:\Users\dell\AppData\Local\pip\Cache\wheels\ad\cf\f3\3cab28f6aed46f15c8db09c6ad678483610426261025e61ff8
# Successfully built spectral
# Installing collected packages: spectral
# Successfully installed spectral-0.20
# Note: you may need to restart the kernel to use updated packages.

# %%
from spectral import *


img = open_image('92AV3C.lan')

img.__class__
# Out:
# spectral.io.bilfile.BilFile

# %%
img.shape
# Out:
# (145, 145, 220)

# %%
pixel = img[50,100]

# %%
pixel.shape
# Out:
# (220,)

# %%
band6 = img[:,:,5]

# %%
band6.shape
# Out:
# (145, 145, 1)

# %%
arr = img.load()

# %%
arr.__class__
# Out:
# spectral.spectral.ImageArray

# %%
print arr.info()
# Out:
#   File "<ipython-input-14-09041f7bc7e9>", line 1
#     print arr.info()
#             ^
# SyntaxError: invalid syntax

# %%
arr.shape
# Out:
# (145, 145, 220)

# %%
 img = open_image('92AV3C.lan')

# %%
img.bands = aviris.read_aviris_bands('92AV3C.spc')

# %%
from spectral import *

# %%
img = open_image('92AV3C.lan')

# %%
 view = imshow(img, (29, 19, 9))gt = open_image('92AV3GT.GIS').read_band(0)

# %%
gt = open_image('92AV3GT.GIS').read_band(0)

# %%
view = imshow(classes=gt)

# %%
view = imshow(img, (30, 20, 10), classes=gt)

# %%
view.set_display_mode('overlay')

# %%
view.class_alpha = 0.5

# %%
import spectral.io.aviris as aviris

# %%
img.bands = aviris.read_aviris_bands('92AV3C.spc')

# %%
from spectral import *

# %%
img = open_image('92AV3C.lan').load()

# %%
view = kmeans(img,20, 30)
# Out:
# Initializing clusters along diagonal of N-dimensional bounding box.
# Iteration 1...  0.Iteration 1...21024 pixels reassigned.
# Iteration 2...  0.Iteration 2...11214 pixels reassigned.
# Iteration 3...  0.Iteration 3...4726 pixels reassigned.
# Iteration 4...  0.Iteration 4...1767 pixels reassigned.
# Iteration 5...  0.Iteration 5...1240 pixels reassigned.
# Iteration 6...  0.Iteration 6...1420 pixels reassigned.
# Iteration 7...  0.Iteration 7...1442 pixels reassigned.
# Iteration 8...  0.Iteration 8...1205 pixels reassigned.
# Iteration 9...  0.Iteration 9...1041 pixels reassigned.
# Iteration 10...  0.0Iteration 10...934 pixels reassigned.
# Iteration 11...  0.0Iteration 11...977 pixels reassigned.
# Iteration 12...  0.0Iteration 12...1027 pixels reassigned.
# Iteration 13...  0.0Iteration 13...1019 pixels reassigned.
# Iteration 14...  0.0Iteration 14...1011 pixels reassigned.
# Iteration 15...  0.0Iteration 15...904 pixels reassigned.
# Iteration 16...  0.0Iteration 16...702 pixels reassigned.
# Iteration 17...  0.0Iteration 17...653 pixels reassigned.
# Iteration 18...  0.0Iteration 18...579 pixels reassigned.
# Iteration 19...  0.0Iteration 19...518 pixels reassigned.
# Iteration 20...  0.0Iteration 20...544 pixels reassigned.
# Iteration 21...  0.0Iteration 21...554 pixels reassigned.
# Iteration 22...  0.0Iteration 22...548 pixels reassigned.
# Iteration 23...  0.0Iteration 23...548 pixels reassigned.
# Iteration 24...  0.0Iteration 24...475 pixels reassigned.
# Iteration 25...  0.0Iteration 25...418 pixels reassigned.
# Iteration 26...  0.0Iteration 26...348 pixels reassigned.
# Iteration 27...  0.0Iteration 27...327 pixels reassigned.
# Iteration 28...  0.0Iteration 28...248 pixels reassigned.
# Iteration 29...  0.0Iteration 29...215 pixels reassigned.
# Iteration 30...  0.0Iteration 30...241 pixels reassigned.
# kmeans terminated with 17 clusters after 30 iterations.

# %%
import pylab

# %%
pylab.figure()

# %%
 for i in range(c.shape[0]):
    
    pylab.plot(c[i])

# %%
pylab.show()

# %%
plt.show()

# %%
gt = open_image('92AV3GT.GIS').read_band(0)

# %%
v = imshow(classes=gt)

# %%
classes = create_training_classes(img, gt)

# %%
gmlc = GaussianClassifier(classes)
# Out:
# Setting min samples to 220
#   Omitting class   1 : only 54 samples present
#   Omitting class   7 : only 26 samples present
#   Omitting class   9 : only 20 samples present
#   Omitting class  13 : only 212 samples present
#   Omitting class  16 : only 95 samples present

# %%
clmap = gmlc.classify_image(img)
# Out:
# Processing...  0.0Processing...  9.1Processing... 18.2Processing... 27.3Processing... 36.4Processing... 45.5Processing... 54.5Processing... 63.6Processing... 72.7Processing... 81.8Processing... 90.9Processing... 100.Processing...done

# %%
 v = imshow(classes=clmap)

# %%
gtresults = clmap * (gt != 0)

# %%
v = imshow(classes=gtresults)

# %%
gterrors = gtresults * (gtresults != gt)

# %%
v = imshow(classes=gterrors)
